# %%
import matplotlib.pyplot as plt
import numpy as np

# Setting gaya visual standar jurnal ilmiah (Landscape style)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 10
# Mengubah susunan menjadi 2 baris (kebawah) dan 3 kolom (kesamping)
fig, axs = plt.subplots(2, 3, figsize=(16, 9), sharex=False)

# ==========================================
# DATASET EXTRACTION FROM LOGS (100% VALID)
# ==========================================
# Model 1: Variety (20 Epochs)
epochs_m1 = np.arange(1, 21)
acc_m1 = [0.6704, 0.8462, 0.8962, 0.9155, 0.9291, 0.9325, 0.9450, 0.9459, 0.9516, 0.9499, 0.9561, 0.9570, 0.9608, 0.9643, 0.9621, 0.9646, 0.9662, 0.9675, 0.9689, 0.9681]
val_acc_m1 = [0.8485, 0.9090, 0.9355, 0.9495, 0.9621, 0.9641, 0.9641, 0.9694, 0.9701, 0.9708, 0.9708, 0.9714, 0.9721, 0.9721, 0.9748, 0.9734, 0.9741, 0.9741, 0.9734, 0.9748]
loss_m1 = [0.7558, 0.3937, 0.2817, 0.2293, 0.2005, 0.1799, 0.1556, 0.1504, 0.1392, 0.1314, 0.1263, 0.1202, 0.1104, 0.1028, 0.1063, 0.0990, 0.0977, 0.0907, 0.0887, 0.0875]
val_loss_m1 = [0.4163, 0.2762, 0.2154, 0.1781, 0.1529, 0.1407, 0.1332, 0.1164, 0.1101, 0.1045, 0.1041, 0.0994, 0.0955, 0.0915, 0.0866, 0.0868, 0.0828, 0.0827, 0.0808, 0.0780]

# Model 2: Ripeness (20 Base + 10 Fine-Tuning = 30 Epochs)
epochs_m2 = np.arange(1, 31)
acc_m2 = [0.7279, 0.8479, 0.8543, 0.8539, 0.8590, 0.8783, 0.8697, 0.8855, 0.8817, 0.8971, 0.8817, 0.8765, 0.8885, 0.8808, 0.8859, 0.8864, 0.8838, 0.9005, 0.8928, 0.8924] + [0.8321, 0.8603, 0.8706, 0.8765, 0.8825, 0.8757, 0.8830, 0.8911, 0.8864, 0.8774]
val_acc_m2 = [0.9133, 0.9133, 0.8800, 0.8967, 0.9100, 0.9133, 0.9200, 0.9167, 0.9133, 0.9267, 0.9267, 0.9233, 0.9267, 0.9233, 0.9233, 0.9233, 0.9167, 0.9200, 0.9267, 0.9267] + [0.9167, 0.9033, 0.9000, 0.9000, 0.9033, 0.9133, 0.9133, 0.9133, 0.9200, 0.9233]
loss_m2 = [0.6514, 0.3687, 0.3722, 0.3543, 0.3461, 0.3156, 0.3255, 0.3003, 0.2973, 0.2810, 0.2986, 0.3079, 0.2756, 0.3066, 0.2979, 0.2772, 0.2925, 0.2616, 0.2788, 0.2681] + [0.4736, 0.3875, 0.3503, 0.3234, 0.3135, 0.3110, 0.3012, 0.2863, 0.3077, 0.2977]
val_loss_m2 = [0.2266, 0.2233, 0.2817, 0.2540, 0.2337, 0.2158, 0.2072, 0.2093, 0.2067, 0.2011, 0.1989, 0.2000, 0.1991, 0.1905, 0.1928, 0.1882, 0.1978, 0.1949, 0.1990, 0.1968] + [0.2314, 0.2586, 0.2717, 0.2712, 0.2602, 0.2537, 0.2436, 0.2338, 0.2265, 0.2192]

# Model 3: Freshness (30 Epochs)
epochs_m3 = np.arange(1, 31)
acc_m3 = [0.8652, 0.9269, 0.9390, 0.9442, 0.9444, 0.9456, 0.9466, 0.9487, 0.9504, 0.9523, 0.9508, 0.9504, 0.9526, 0.9500, 0.9503, 0.9522, 0.9536, 0.9511, 0.9492, 0.9544, 0.9519, 0.9520, 0.9505, 0.9548, 0.9540, 0.9539, 0.9554, 0.9524, 0.9534, 0.9558]
val_acc_m3 = [0.9477, 0.9592, 0.9674, 0.9663, 0.9726, 0.9733, 0.9755, 0.9755, 0.9770, 0.9766, 0.9729, 0.9752, 0.9778, 0.9792, 0.9766, 0.9770, 0.9770, 0.9770, 0.9774, 0.9774, 0.9770, 0.9774, 0.9770, 0.9781, 0.9774, 0.9770, 0.9774, 0.9778, 0.9774, 0.9774]
loss_m3 = [0.3046, 0.1824, 0.1537, 0.1438, 0.1393, 0.1343, 0.1383, 0.1265, 0.1236, 0.1210, 0.1225, 0.1267, 0.1203, 0.1276, 0.1230, 0.1195, 0.1244, 0.1228, 0.1266, 0.1225, 0.1226, 0.1231, 0.1206, 0.1233, 0.1208, 0.1180, 0.1167, 0.1219, 0.1197, 0.1169]
val_loss_m3 = [0.1394, 0.1130, 0.0979, 0.0896, 0.0829, 0.0821, 0.0765, 0.0745, 0.0718, 0.0720, 0.0736, 0.0708, 0.0696, 0.0705, 0.0714, 0.0706, 0.0694, 0.0697, 0.0693, 0.0693, 0.0691, 0.0691, 0.0694, 0.0693, 0.0692, 0.0692, 0.0693, 0.0691, 0.0692, 0.0691]

# ==========================================
# RESTRUCTURED PLOTTING MECHANISM
# ==========================================
def plot_curves(model_idx, epochs, train_data, val_data, title, ylabel, is_loss=False):
    # Baris ditentukan oleh tipe data (Row 0 untuk Accuracy, Row 1 untuk Loss)
    row_idx = 1 if is_loss else 0
    # Kolom ditentukan oleh jenis model (Col 0: Variety, Col 1: Ripeness, Col 2: Freshness)
    ax = axs[row_idx, model_idx]
    
    c_train = '#d95f02' if is_loss else '#1f77b4'
    c_val = '#e7298a' if is_loss else '#2ca02c'
    
    ax.plot(epochs, train_data, color=c_train, linewidth=1.8, label='Training')
    ax.plot(epochs, val_data, color=c_val, linewidth=1.8, linestyle='--', label='Validation')
    
    ax.set_title(title, fontsize=10, fontweight='bold')
    ax.set_xlabel('Epochs', fontsize=9)
    ax.set_ylabel(ylabel, fontsize=9)
    ax.grid(True, linestyle=':', alpha=0.6)
    ax.legend(loc='best', fontsize=8)
    
    # Penanda fase fine-tuning Model 2 (sekarang berada di Kolom Indeks 1)
    if model_idx == 1:
        ax.axvline(x=20, color='red', linestyle=':', linewidth=1.2)
        ax.text(20.5, np.max(train_data)*0.85 if is_loss else 0.76, 'Fine-Tuning\nStarted', color='red', fontsize=7)

# --- KOLOM 0: Model Varietas (Fruit Variety) ---
plot_curves(0, epochs_m1, acc_m1, val_acc_m1, '(a) Fruit Variety: Accuracy', 'Accuracy')
plot_curves(0, epochs_m1, loss_m1, val_loss_m1, '(b) Fruit Variety: Categorical Cross-Entropy Loss', 'Loss', is_loss=True)

# --- KOLOM 1: Model Kematangan (Fruit Ripeness) ---
plot_curves(1, epochs_m2, acc_m2, val_acc_m2, '(c) Fruit Ripeness: Accuracy', 'Accuracy')
plot_curves(1, epochs_m2, loss_m2, val_loss_m2, '(d) Fruit Ripeness: Categorical Cross-Entropy Loss', 'Loss', is_loss=True)

# --- KOLOM 2: Model Kesegaran (Fruit Freshness) ---
plot_curves(2, epochs_m3, acc_m3, val_acc_m3, '(e) Fruit Freshness: Accuracy', 'Accuracy')
plot_curves(2, epochs_m3, loss_m3, val_loss_m3, '(f) Fruit Freshness: Binary Cross-Entropy Loss', 'Loss', is_loss=True)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=300, bbox_inches='tight')
print("[SUCCESS] Grafik 'training_curves.png' (Tata Letak Lanskap 2x3) berhasil dibuat!")
# Out:
# [SUCCESS] Grafik 'training_curves.png' (Tata Letak Lanskap 2x3) berhasil dibuat!
